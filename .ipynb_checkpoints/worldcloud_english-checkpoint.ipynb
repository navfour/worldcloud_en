# %%
filename = "guns n ross.txt"
with open(filename) as f:
 mytext = f.read()

# %%
from wordcloud import WordCloud
wordcloud = WordCloud().generate(mytext)

# %%
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)
